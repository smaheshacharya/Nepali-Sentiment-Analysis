# %%
a = np.array([1])
b= a.reshape(1,40)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-d8227d6ee63d> in <module>()
#       1 a = [1]
# ----> 2 b= a.reshape(1,40)
#
# AttributeError: 'list' object has no attribute 'reshape'
